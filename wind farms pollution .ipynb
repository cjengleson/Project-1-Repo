# %%
import pandas as pd

# %%
file_one = "Resources/uspollutionryan.csv"

# %%
file_one_df = pd.read_csv(file_one)

# %%
file_one_df.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#   Date Local          NO2 Units  ...          SO2 Units  SO2 Mean  \
# 0   1/1/2000  Parts per billion  ...  Parts per billion  3.000000
# 1   1/1/2000  Parts per billion  ...  Parts per billion  3.000000
# ...

# %%
reduced_df = file_one_df[["State", "County", "SO2 Mean", "CO Mean"]]
reduced_df.head()
# Out:
#      State    County  SO2 Mean   CO Mean
# 0  Arizona  Maricopa  3.000000  1.145833
# 1  Arizona  Maricopa  3.000000  0.878947
# 2  Arizona  Maricopa  2.975000  1.145833
# 3  Arizona  Maricopa  2.975000  0.878947
# 4  Arizona  Maricopa  1.958333  0.850000

# %%
reduced_df.describe()
# Out:
#            SO2 Mean       CO Mean
# count  1.048575e+06  1.048575e+06
# mean   2.488623e+00  4.221252e-01
# std    3.220715e+00  3.601106e-01
# min   -4.545450e-01  0.000000e+00
# 25%    4.571430e-01  2.000000e-01
# 50%    1.425000e+00  3.391300e-01
# 75%    3.291667e+00  5.416670e-01
# max    3.216250e+02  7.508333e+00
