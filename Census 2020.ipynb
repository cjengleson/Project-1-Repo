# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# %%
# Census data 2019
# Census API Key
from config import api_key
c = Census(api_key, year=2019)

census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

census_pd["Year"] = 2019

# Final DataFrame
census_pd2019 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2019))
census_pd2019.head()
# Out:
# 33120
#   Zipcode  Year  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601  2019     17113.0        41.9           14361.0             7493.0
# 1   00602  2019     37751.0        42.9           16807.0             9694.0
# 2   00603  2019     47081.0        42.1           16049.0            11259.0
# 3   00606  2019      6392.0        44.3           12119.0             6093.0
# 4   00610  2019     26686.0        42.7           19898.0            10572.0
#
#    Poverty Count
# 0        10552.0
# 1        18653.0
# 2        23691.0
# 3         4185.0
# 4        12204.0

# %%
# Census data 2018
from config import api_key
c = Census(api_key, year=2018)

census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

census_pd["Year"] = 2018

# Final DataFrame
census_pd2018 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2018))
census_pd2018.head()
# Out:
# 33120
#   Zipcode  Year  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601  2018     17242.0        40.5           13092.0             6999.0
# 1   00602  2018     38442.0        42.3           16358.0             9277.0
# 2   00603  2018     48814.0        41.1           16603.0            11307.0
# 3   00606  2018      6437.0        43.3           12832.0             5943.0
# 4   00610  2018     27073.0        42.1           19309.0            10220.0
#
#    Poverty Count
# 0        10772.0
# 1        19611.0
# 2        24337.0
# 3         4163.0
# 4        11724.0

# %%
# Census data 2017
from config import api_key
c = Census(api_key, year=2017)

census_data = c.acs1.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'county:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "county": "County"})

census_pd["Year"] = 2017

# Final DataFrame
census_pd2017 = census_pd[["Name", "County", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2017))
census_pd2017.head()
# Out:
# 837
#                             Name County  Year  Population  Median Age  \
# 0  St. Lawrence County, New York    089  2017    109623.0        39.1
# 1      Saratoga County, New York    091  2017    229869.0        43.0
# 2   Schenectady County, New York    093  2017    155565.0        40.1
# 3       Steuben County, New York    101  2017     96281.0        43.1
# 4       Suffolk County, New York    103  2017   1492953.0        41.1
#
#    Household Income  Per Capita Income  Poverty Count
# 0           50325.0            24267.0        18938.0
# 1           83726.0            42756.0        14447.0
# 2           62514.0            30210.0        19434.0
# 3           50930.0            27347.0        11691.0
# 4           94750.0            41331.0        99225.0

# %%
# Census data 2016
from config import api_key
c = Census(api_key, year=2016)

census_data = c.acs1.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'county:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "county": "County"})

census_pd["Year"] = 2016

# Final DataFrame
census_pd2016 = census_pd[["Name", "County", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2016))
census_pd2016.head()
# Out:
# 831
#                          Name County  Year  Population  Median Age  \
# 0  Craighead County, Arkansas    031  2016    105835.0        34.5
# 1   Faulkner County, Arkansas    045  2016    122227.0        33.1
# 2    Garland County, Arkansas    051  2016     97477.0        44.0
# 3  Jefferson County, Arkansas    069  2016     70016.0        39.0
# 4     Lonoke County, Arkansas    085  2016     72228.0        36.4
#
#    Household Income  Per Capita Income  Poverty Count
# 0           43678.0            25491.0        16602.0
# 1           48506.0            24526.0        22285.0
# 2           42826.0            24263.0        17824.0
# 3           37712.0            20521.0        14565.0
# 4           55837.0            24910.0        10548.0

# %%
# Census data 2016
from config import api_key
c = Census(api_key, year=2015)

census_data = c.acs1.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'county:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "county": "County"})

census_pd["Year"] = 2015

# Final DataFrame
census_pd2015 = census_pd[["Name", "County", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2015))
census_pd2015.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-bb8074616192> in <module>
#       3 c = Census(api_key, year=2015)
#       4
# ----> 5 census_data = c.acs1.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
#       6                           "B19301_001E",
#       7                           "B17001_002E"), {'for': 'county:*'})
#
# ~\anaconda3\lib\site-packages\census\core.py in get(self, *args, **kwargs)
#     275         self._switch_endpoints(kwargs.get('year', self.default_year))
#     276
# --> 277         return super(ACSClient, self).get(*args, **kwargs)
#     278
#     279 class ACS5Client(ACSClient):
#
# ~\anaconda3\lib\site-packages\census\core.py in get(self, fields, geo, year, **kwargs)
#     132         all_results = (self.query(fifty_fields, geo, year, **kwargs)
#     133                        for fifty_fields in chunks(fields, 50))
# --> 134         merged_results = [merge(result) for result in zip(*all_results)]
#     135
#     136         return merged_results
#
# ~\anaconda3\lib\site-packages\census\core.py in <genexpr>(.0)
#     130
#     131     def get(self, fields, geo, year=None, **kwargs):
# --> 132         all_results = (self.query(fifty_fields, geo, year, **kwargs)
#     133                        for fifty_fields in chunks(fields, 50))
#     134         merged_results = [merge(result) for result in zip(*all_results)]
#
# ~\anaconda3\lib\site-packages\census\core.py in query(self, fields, geo, year, **kwargs)
#     165                     raise ex
#     166
# --> 167             headers = data.pop(0)
#     168             types = [self._field_type(header, year) for header in headers]
#     169             results = [{header : (cast(item) if item is not None else None)
#
# KeyError: 0

# %%
# Census data 2014
from config import api_key
c = Census(api_key, year=2014)

census_data = c.acs1.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'county:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "county": "County"})
census_pd["Year"] = 2014

# Final DataFrame
census_pd2014 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2014))
census_pd2014.head()
