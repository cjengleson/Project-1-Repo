# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API Key
from config import api_key
c = Census(api_key, year=2019)

# %%
# Census data 2019
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

census_pd["Year"] = 2019

# Final DataFrame
census_pd2019 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2019))
census_pd2019.head()
# Out:
# 33120
#   Zipcode  Year  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601  2019     17113.0        41.9           14361.0             7493.0
# 1   00602  2019     37751.0        42.9           16807.0             9694.0
# 2   00603  2019     47081.0        42.1           16049.0            11259.0
# 3   00606  2019      6392.0        44.3           12119.0             6093.0
# 4   00610  2019     26686.0        42.7           19898.0            10572.0
#
#    Poverty Count
# 0        10552.0
# 1        18653.0
# 2        23691.0
# 3         4185.0
# 4        12204.0

# %%
# Census data 2018
from config import api_key
c = Census(api_key, year=2018)

census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

census_pd["Year"] = 2018

# Final DataFrame
census_pd2018 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2018))
census_pd2018.head()
# Out:
# 33120
#   Zipcode  Year  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601  2018     17242.0        40.5           13092.0             6999.0
# 1   00602  2018     38442.0        42.3           16358.0             9277.0
# 2   00603  2018     48814.0        41.1           16603.0            11307.0
# 3   00606  2018      6437.0        43.3           12832.0             5943.0
# 4   00610  2018     27073.0        42.1           19309.0            10220.0
#
#    Poverty Count
# 0        10772.0
# 1        19611.0
# 2        24337.0
# 3         4163.0
# 4        11724.0

# %%
# Census data 2017
from config import api_key
c = Census(api_key, year=2017)

census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

census_pd["Year"] = 2017

# Final DataFrame
census_pd2017 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2017))
census_pd2017.head()
# Out:
# 33120
#   Zipcode  Year  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601  2017     17599.0        38.9           11757.0             7041.0
# 1   00602  2017     39209.0        40.9           16190.0             8978.0
# 2   00603  2017     50135.0        40.4           16645.0            10897.0
# 3   00606  2017      6304.0        42.8           13387.0             5960.0
# 4   00610  2017     27590.0        41.4           18741.0             9266.0
#
#    Poverty Count
# 0        11282.0
# 1        20428.0
# 2        25176.0
# 3         4092.0
# 4        12553.0

# %%
# Census data 2016
from config import api_key
c = Census(api_key, year=2016)

census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

census_pd["Year"] = 2016

# Final DataFrame
census_pd2016 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2016))
census_pd2016.head()
# Out:
# 33120
#   Zipcode  Year  Population  Median Age  Household Income  Per Capita Income  \
# 0   05762  2016       513.0        39.2           58558.0            24235.0
# 1   05763  2016      2715.0        43.9           54968.0            29674.0
# 2   05764  2016      3370.0        41.3           44468.0            22651.0
# 3   05765  2016      1632.0        46.7           56771.0            30786.0
# 4   05766  2016       598.0        45.9           52250.0            33227.0
#
#    Poverty Count
# 0           50.0
# 1          488.0
# 2          323.0
# 3           85.0
# 4           76.0

# %%
# Census data 2015
from config import api_key
c = Census(api_key, year=2015)

census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

census_pd["Year"] = 2015

# Final DataFrame
census_pd2014 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2015))
census_pd2015.head()
# Out:
# ---------------------------------------------------------------------------
# CensusException                           Traceback (most recent call last)
# <ipython-input-52-684a027d9890> in <module>
#       3 c = Census(api_key, year=2015)
#       4
# ----> 5 census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
#       6                           "B19301_001E",
#       7                           "B17001_002E"), {'for': 'zip code tabulation area:*'})
#
# ~\anaconda3\lib\site-packages\census\core.py in get(self, *args, **kwargs)
#     275         self._switch_endpoints(kwargs.get('year', self.default_year))
#     276
# --> 277         return super(ACSClient, self).get(*args, **kwargs)
#     278
#     279 class ACS5Client(ACSClient):
#
# ~\anaconda3\lib\site-packages\census\core.py in get(self, fields, geo, year, **kwargs)
#     132         all_results = (self.query(fifty_fields, geo, year, **kwargs)
# ...

# %%
# Census data 2014
from config import api_key
c = Census(api_key, year=2014)

census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})


census_pd["Year"] = 2014

# Final DataFrame
census_pd2014 = census_pd[["Zipcode", "Year","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]

# Visualize
print(len(census_pd2014))
census_pd2014.head()
# Out:
# ---------------------------------------------------------------------------
# CensusException                           Traceback (most recent call last)
# <ipython-input-48-a5c25e14297f> in <module>
#       3 c = Census(api_key, year=2014)
#       4
# ----> 5 census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
#       6                           "B19301_001E",
#       7                           "B17001_002E"), {'for': 'zip code tabulation area:*'})
#
# ~\anaconda3\lib\site-packages\census\core.py in get(self, *args, **kwargs)
#     275         self._switch_endpoints(kwargs.get('year', self.default_year))
#     276
# --> 277         return super(ACSClient, self).get(*args, **kwargs)
#     278
#     279 class ACS5Client(ACSClient):
#
# ~\anaconda3\lib\site-packages\census\core.py in get(self, fields, geo, year, **kwargs)
#     132         all_results = (self.query(fifty_fields, geo, year, **kwargs)
# ...
